# %% [markdown]
# <a href="https://colab.research.google.com/github/VinayKumarMakvana/FSD-By-Skillected-2025-2026/blob/main/DAY_8_Data_type.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DAY 8**
# ### **DATA TYPE**

# %% [markdown]
# **Collaction Data Type**

# %% [markdown]
# List

# %%
# Collection data type :- it is use to store multiple values in a single variable

# MAIN TYPE

# 1. LIST :- order and changable(Mutable)
# 2. TUPLE :- order and not changeble
# 3. SET :- unorder and unique
# 4. DICTIONARY :- key-value pair

# %%
# List :- list is a conection of multiple item stored in a single variable

items=["Leptop","Mouse","Keyboard"]
print(items)
# Out:
# Keyboard

# %%
# Add data
# append() :- add items at end.

items.append("mobile")

# %%
print(items)
# Out:
# ['Leptop', 'Mouse', 'Keyboard', 'mobile']

# %%
# insert():- using index through adding.
items.insert(2,"tab")

# %%
print(items)
# Out:
# ['tab', 'Leptop', 'tab', 'tab', 'tab', 'Mouse', 'Keyboard', 'mobile']

# %%
# modify
items[1]="headphone"
items
# Out:
# ['tab', 'headphone', 'tab', 'tab', 'tab', 'Mouse', 'Keyboard', 'mobile']

# %%
# remove()
# items.remove("tab")

items
# Out:
# ['headphone', 'tab', 'Mouse', 'Keyboard', 'mobile']

# %%
# pop()
items.pop(0)
# Out:
# 'headphone'

# %%
items
# Out:
# ['tab', 'Mouse']

# %%
items=['tab', 'headphone', 'tab', 'tab', 'tab', 'Mouse', 'Keyboard', 'mobile']
print(items)
# Out:
# ['tab', 'headphone', 'tab', 'tab', 'tab', 'Mouse', 'Keyboard', 'mobile']

# %%
for item in items:
  print(item)
# Out:
# tab
# headphone
# tab
# tab
# tab
# Mouse
# Keyboard
# mobile

# %%
marks=[85,90,78,60,97]
print(marks)
# Out:
# [85, 90, 78, 60, 97]

# %%
print(max(marks))
print(min(marks))
print(sum(marks))
# Out:
# 97
# 60
# 410

# %%
# PROJECT

students=[]
while True:
  name=input("Enter Name:(exit to stop)")
  if name=="exit":
    break
  students.append(name)
print(students);
# Out:
# Enter Name:(exit to stop)vinay
# Enter Name:(exit to stop)akash
# Enter Name:(exit to stop)priya
# Enter Name:(exit to stop)urmilaa
# Enter Name:(exit to stop)ravi
# Enter Name:(exit to stop)exit
# ['vinay', 'akash', 'priya', 'urmilaa', 'ravi']

# %%
# home work
# card system hetrogenous
# mark system and
# price system that sum at end.

# Hetrogenous and homogenous

# homogeneous:- Same datatype
number=[1,2,3,4,5]

# heterogenous:- different DATATYPES
data=["vinay",24,True,85.2]

# list kaha store hoti he?
# Lists are stored in non-volatile storage (like hard drives, SSDs, or databases)
# to retain data when the power is turned off, or in volatile storage (RAM) for temporary, fast access.

# %%
# card system hetrogenous.

cards = []

n = int(input("Enter number of cards: "))

for i in range(n):
    print("\nEnter details of card", i+1)

    name = input("Enter name: ")
    Quantity = int(input("Enter Quantity: "))
    price = float(input("Enter price: "))

    card = {
        "name": name,
        "Quantity": Quantity,
        "price": price
    }

    cards.append(card)

print("\n--- Card Details ---")
for c in cards:
    print(c)
# Out:
# Enter number of cards: 2
#
# Enter details of card 1
# Enter name: ch
# Enter Quantity: 5
# Enter price: 50
#
# Enter details of card 2
# Enter name: gfxfg
# Enter Quantity: 2
# Enter price: 100
#
# --- Card Details ---
# {'name': 'ch', 'Quantity': 5, 'price': 50.0}
# {'name': 'gfxfg', 'Quantity': 2, 'price': 100.0}

# %%
# Mark system in Python

students = []

n = int(input("Enter number of students: "))

for i in range(n):
    print("\nEnter details for student", i+1)

    name = input("Name: ")
    marks = int(input("Marks: "))

    student = {
        "name": name,
        "marks": marks
    }

    students.append(student)

total_marks = 0

print("\n--- Student Marks ---")
for s in students:
    print(f"Name: {s['name']}, Marks: {s['marks']}")
    total_marks += s['marks']

average = total_marks / n

print("\n--- Result ---")
print("Total Marks:", total_marks)
print("Average Marks:", average)
# Out:
# Enter number of students: 3
#
# Enter details for student 1
# Name: vinay
# Marks: 820
#
# Enter details for student 2
# Name: ajay
# Marks: 874
#
# Enter details for student 3
# Name: akash
# Marks: 750
#
# --- Student Marks ---
# Name: vinay, Marks: 820
# Name: ajay , Marks: 874
# Name: akash, Marks: 750
#
# --- Result ---
# Total Marks: 2444
# Average Marks: 814.6666666666666

# %%
# Price system with total sum
items = []

n = int(input("Enter number of items: "))

for i in range(n):
    print("\nEnter item", i+1)

    name = input("Item name: ")
    price = float(input("Item price: "))

    item = {
        "name": name,
        "price": price
    }

    items.append(item)

total_price = 0

print("\n--- Item List ---")
for item in items:
    print(f"Item: {item['name']}, Price: {item['price']}")
    total_price += item['price']

print("\n--- Total ---")
print("Total Price:", total_price)
# Out:
# Enter number of items: 2
#
# Enter item 1
# Item name: kak
# Item price: 500
#
# Enter item 2
# Item name: khba
# Item price: 300
#
# --- Item List ---
# Item: kak, Price: 500.0
# Item: khba, Price: 300.0
#
# --- Total ---
# Total Price: 800.0
